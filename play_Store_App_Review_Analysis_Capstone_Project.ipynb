# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghanah97/Playstore_data_analysis/blob/main/play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# # “Technology is best when it brings people together.”

# %% [markdown]
# The hottest marketing and publicity tool around now is a mobile app, this is because of its numerous benefits. In fact, mobiles apps have become indispensable to businesses of today. Mobile application or mobile apps is a type of application software that have been designed for many purposes for people. Mobile apps can be run in any type of handset, including tablets and smart phones, literally we can get an app in our finger tips without struggling. At present, apps are frequently used by people for many reasons. One of the reasons are to ease their daily life tasks. Given this it is important to anlyze key factors responsible for engagement and success

# %% [markdown]
# **What we are upto?**\
# 1.Exploration namely:Head, tail, summary,data dictionary\
# 2.Looking for and handling NaN/Null/Missing Values\
# 3.Trying to get some conclusion from data,correlation, trends and making sense in doing so\
# 4.Variuous milestone given in the problem statement\
# 5.Using visualization for presnting the EDA\
# 6.Final summary of conclusion

# %%
#import statements
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import plotly.graph_objs as go
from wordcloud import WordCloud

# %%
ply=pd.read_csv('/content/Play Store Data.csv')
usr=pd.read_csv('/content/User Reviews.csv')

# %%
#Basic exploration on dataframe
ply.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
ply.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
usr.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
usr.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
ply.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
ply.shape
# Out:
# (10841, 13)

# %%
usr.shape
# Out:
# (64295, 5)

# %% [markdown]
# With above exploration playstore dataframe has 10841 rows and 13 columns and user review dataframe has 64295 rows and 5 columns
# # Playstore dataframe columns are:
#
# 1.App: This column gives App name
#
# 2.Category: This column is about category of respective App like family, game etc
#
# 3.Rating: This column is about rating given by user on respective App, it varies from 1 to 5
#
# 4.Reviews: This column has star rating as well as text comment
#
# 5.Size: This column gives size of App
#
# 6.Installs: This column gives count on installs in particular App
#
# 7.Type: This column gives information on whether App is free or paid \
#
# 8.Price: If above column type is paid, mentions price of respective App
#
# 9.Content Rating: This column gives content name of respective App like Everyone,Mature 17+
#
# 10.Genres: This column represent which style or category  App is about like education, astrology etc
#
# 11.Last updated: This column is about the when the App was updated.
#
# 12.Current ver: This column is about the current version of the App.
#
# 13.Android Ver: This column is about the android version which can support the App on its platform.
# # Similiarly User review columns are:
# 1. App:  This column gives App name
#
# 2. Translated_review: this column about review given by user
#
# 3. Sentiment: this column distinguish between positive, negative and nuetral.
#
# 4. Sentiment_Polarity: It defines the orientation of the expressed sentiment, ranges from [-1,1]
#
# 5. Sentiment_Subjectivity: It defines the orientation of the expressed sentiment, ranges from [0,1]

# %% [markdown]
# # **Data cleaning**
# Removing unwanted values,unwanted outliers, replacing missing values.

# %%
ply.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
ply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Columns like Reviews, Size, Installs, & price should have an int or float datatype, But here we can see of object type, So let’s convert them to their respective correct type.

# %% [markdown]
# From above output we can see rating has float/int datatype ,hence it is represented in boxplot.

# %%
ply.boxplot();

# %% [markdown]
# Here we can Rating column has outlier, rating can only between 1-5,here it is greater than 17.5.hence there is outlier,needs to be corrected.

# %% [markdown]
# # Category and Rating

# %%
ply['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
ply[ply['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# We can see Category have wrong value i.e. 1.9 and rating have outlier.So it should be removed.

# %%
#dropping outlier column
ply.drop([10472],inplace=True)

# %%
ply['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# We will check unique values of each column.

# %%
ply['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
ply['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
ply['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %% [markdown]
# # Size
# Converting the Size Column from object to integer, but this column contains some of the special characters like , , + , M , K & also it has a some of the value as Varies with device . We need to remove all of these and then convert it to int or float

# %%
ply['Size'] = ply['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
ply['Size'] = ply['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
ply['Size'] = ply['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
ply['Size'] = ply['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
ply['Size'] = ply['Size'].apply(lambda x: float(x))
ply.dropna(subset = ['Size'], inplace=True)
ply['Size'].dtype
# Out:
# dtype('float64')

# %%
ply['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01, 9.40e+00,
#        1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00, 7.90e+00,
#        5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01, 3.60e+00,
#        5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00, 1.60e+01,
#        3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01, 3.20e+01,
#        5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00, 9.80e+00,
#        5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00, 7.10e+00,
#        3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00, 8.20e+00,
#        9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00, 1.30e+01,
#        7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00, 7.20e+00,
#        2.10e+00, 4.20e+01, 7.30e+00, 9.10e+00, 5.50e+01, 2.30e-02,
#        6.50e+00, 1.50e+00, 7.50e+00, 5.10e+01, 4.10e+01, 4.80e+01,
#        8.50e+00, 4.60e+01, 8.30e+00, 4.30e+00, 4.70e+00, 3.30e+00,
#        4.00e+01, 7.80e+00, 8.80e+00, 6.60e+00, 5.10e+00, 6.10e+01,
#        6.60e+01, 7.90e-02, 8.40e+00, 1.18e-01, 4.40e+01, 6.95e-01,
#        1.60e+00, 6.20e+00, 1.80e-02, 5.30e+01, 1.40e+00, 3.00e+00,
#        5.80e+00, 3.80e+00, 9.60e+00, 4.50e+01, 6.30e+01, 4.90e+01,
#        7.70e+01, 4.40e+00, 4.80e+00, 7.00e+01, 6.90e+00, 9.30e+00,
#        8.10e+00, 3.60e+01, 8.40e+01, 9.70e+01, 2.00e+00, 1.90e+00,
#        1.80e+00, 5.30e+00, 4.70e+01, 5.56e-01, 5.26e-01, 7.60e+01,
#        7.60e+00, 5.90e+01, 9.70e+00, 7.80e+01, 7.20e+01, 4.30e+01,
#        7.70e+00, 6.30e+00, 3.34e-01, 3.40e+01, 9.30e+01, 6.50e+01,
#        7.90e+01, 1.00e+02, 5.80e+01, 5.00e+01, 6.80e+01, 6.40e+01,
#        6.70e+01, 6.00e+01, 9.40e+01, 2.32e-01, 9.90e+01, 6.24e-01,
#        9.50e+01, 8.50e-03, 4.10e-02, 2.92e-01, 1.10e-02, 8.00e+01,
#        1.70e+00, 7.40e+01, 6.20e+01, 6.90e+01, 7.50e+01, 9.80e+01,
#        8.50e+01, 8.20e+01, 9.60e+01, 8.70e+01, 7.10e+01, 8.60e+01,
#        9.10e+01, 8.10e+01, 9.20e+01, 8.30e+01, 8.80e+01, 7.04e-01,
#        8.62e-01, 8.99e-01, 3.78e-01, 2.66e-01, 3.75e-01, 1.30e+00,
#        9.75e-01, 9.80e-01, 4.10e+00, 8.90e+01, 6.96e-01, 5.44e-01,
#        5.25e-01, 9.20e-01, 7.79e-01, 8.53e-01, 7.20e-01, 7.13e-01,
#        7.72e-01, 3.18e-01, 5.80e-02, 2.41e-01, 1.96e-01, 8.57e-01,
#        5.10e-02, 9.53e-01, 8.65e-01, 2.51e-01, 9.30e-01, 5.40e-01,
#        3.13e-01, 7.46e-01, 2.03e-01, 2.60e-02, 3.14e-01, 2.39e-01,
#        3.71e-01, 2.20e-01, 7.30e-01, 7.56e-01, 9.10e-02, 2.93e-01,
#        1.70e-02, 7.40e-02, 1.40e-02, 3.17e-01, 7.80e-02, 9.24e-01,
#        9.02e-01, 8.18e-01, 8.10e-02, 9.39e-01, 1.69e-01, 4.50e-02,
#        4.75e-01, 9.65e-01, 9.00e+01, 5.45e-01, 6.10e-02, 2.83e-01,
#        6.55e-01, 7.14e-01, 9.30e-02, 8.72e-01, 1.21e-01, 3.22e-01,
#        1.00e+00, 9.76e-01, 1.72e-01, 2.38e-01, 5.49e-01, 2.06e-01,
#        9.54e-01, 4.44e-01, 7.17e-01, 2.10e-01, 6.09e-01, 3.08e-01,
#        7.05e-01, 3.06e-01, 9.04e-01, 4.73e-01, 1.75e-01, 3.50e-01,
#        3.83e-01, 4.54e-01, 4.21e-01, 7.00e-02, 8.12e-01, 4.42e-01,
#        8.42e-01, 4.17e-01, 4.12e-01, 4.59e-01, 4.78e-01, 3.35e-01,
#        7.82e-01, 7.21e-01, 4.30e-01, 4.29e-01, 1.92e-01, 2.00e-01,
#        4.60e-01, 7.28e-01, 4.96e-01, 8.16e-01, 4.14e-01, 5.06e-01,
#        8.87e-01, 6.13e-01, 2.43e-01, 5.69e-01, 7.78e-01, 6.83e-01,
#        5.92e-01, 3.19e-01, 1.86e-01, 8.40e-01, 6.47e-01, 1.91e-01,
#        3.73e-01, 4.37e-01, 5.98e-01, 7.16e-01, 5.85e-01, 9.82e-01,
#        2.22e-01, 2.19e-01, 5.50e-02, 9.48e-01, 3.23e-01, 6.91e-01,
#        5.11e-01, 9.51e-01, 9.63e-01, 2.50e-02, 5.54e-01, 3.51e-01,
#        2.70e-02, 8.20e-02, 2.08e-01, 9.13e-01, 5.14e-01, 5.51e-01,
#        2.90e-02, 1.03e-01, 8.98e-01, 7.43e-01, 1.16e-01, 1.53e-01,
#        2.09e-01, 3.53e-01, 4.99e-01, 1.73e-01, 5.97e-01, 8.09e-01,
#        1.22e-01, 4.11e-01, 4.00e-01, 8.01e-01, 7.87e-01, 2.37e-01,
#        5.00e-02, 6.43e-01, 9.86e-01, 9.70e-02, 5.16e-01, 8.37e-01,
#        7.80e-01, 9.61e-01, 2.69e-01, 2.00e-02, 4.98e-01, 6.00e-01,
#        7.49e-01, 6.42e-01, 8.81e-01, 7.20e-02, 6.56e-01, 6.01e-01,
#        2.21e-01, 2.28e-01, 1.08e-01, 9.40e-01, 1.76e-01, 3.30e-02,
#        6.63e-01, 3.40e-02, 9.42e-01, 2.59e-01, 1.64e-01, 4.58e-01,
#        2.45e-01, 6.29e-01, 2.80e-02, 2.88e-01, 7.75e-01, 7.85e-01,
#        6.36e-01, 9.16e-01, 9.94e-01, 3.09e-01, 4.85e-01, 9.14e-01,
#        9.03e-01, 6.08e-01, 5.00e-01, 5.40e-02, 5.62e-01, 8.47e-01,
#        9.57e-01, 6.88e-01, 8.11e-01, 2.70e-01, 4.80e-02, 3.29e-01,
#        5.23e-01, 9.21e-01, 8.74e-01, 9.81e-01, 7.84e-01, 2.80e-01,
#        2.40e-02, 5.18e-01, 7.54e-01, 8.92e-01, 1.54e-01, 8.60e-01,
#        3.64e-01, 3.87e-01, 6.26e-01, 1.61e-01, 8.79e-01, 3.90e-02,
#        9.70e-01, 1.70e-01, 1.41e-01, 1.60e-01, 1.44e-01, 1.43e-01,
#        1.90e-01, 3.76e-01, 1.93e-01, 2.46e-01, 7.30e-02, 6.58e-01,
#        9.92e-01, 2.53e-01, 4.20e-01, 4.04e-01, 4.70e-01, 2.26e-01,
#        2.40e-01, 8.90e-02, 2.34e-01, 2.57e-01, 8.61e-01, 4.67e-01,
#        1.57e-01, 4.40e-02, 6.76e-01, 6.70e-02, 5.52e-01, 8.85e-01,
#        1.02e+00, 5.82e-01, 6.19e-01])

# %% [markdown]
# # Price
# The values contain a special symbol $ which can be removed and then converted to the numeric type.

# %%
ply['Price'] = ply.Price.replace("Everyone",np.nan)
ply['Price'] = ply.Price.replace('$','')
ply['Price'] = ply.Price.str.replace("$","").astype(float)
ply['Price'] = pd.to_numeric(ply['Price'])
ply['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Installs
# To convert Installs column from object to integer type. First of all, we will need to remove the '+',','symbol from these values.

# %%
ply['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000+', '500,000,000+', '50+', '100+', '500+', '10+', '1+', '5+',
#        '1,000,000,000+', '0+'], dtype=object)

# %%
ply['Installs'] = ply.Installs.apply(lambda x: x.strip('+'))
ply['Installs'] = ply.Installs.apply(lambda x: x.replace(',', ''))
ply['Installs'] = pd.to_numeric(ply['Installs'])
ply['Installs'].dtype
# Out:
# dtype('int64')

# %%
ply['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#              1000,  500000000,         50,        100,        500,
#                10,          1,          5, 1000000000,          0])

# %% [markdown]
# # Reviews
# Converting Review's type to int,replacing corresponding values.

# %%
ply['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
ply['Reviews'] = ply.Reviews.replace("0.0",0)
ply['Reviews'] = ply.Reviews.replace("3.0M",3000000)
ply['Reviews'] = ply.Reviews.astype(int)
ply['Reviews'].dtype
# Out:
# dtype('int64')

# %%
ply['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %% [markdown]
# # Last updated
# Converting column last updated datatype to datetime

# %%
ply['Last Updated'] = pd.to_datetime(ply['Last Updated'])
ply['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10835   2016-09-29
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10840   2018-07-25
# Name: Last Updated, Length: 9145, dtype: datetime64[ns]

# %%
ply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9145 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9145 non-null   object
#  1   Category        9145 non-null   object
#  2   Rating          7729 non-null   float64
#  3   Reviews         9145 non-null   int64
#  4   Size            9145 non-null   float64
#  5   Installs        9145 non-null   int64
#  6   Type            9145 non-null   object
#  7   Price           9145 non-null   float64
#  8   Content Rating  9145 non-null   object
#  9   Genres          9145 non-null   object
#  10  Last Updated    9145 non-null   datetime64[ns]
#  11  Current Ver     9137 non-null   object
#  12  Android Ver     9143 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 1000.2+ KB

# %%
#removing duplicate values in App column
total = ply.isnull().sum().sort_values(ascending  = False)
ply.drop_duplicates(subset = 'App', keep = 'first' ,inplace = True)
ply.dropna(how = 'any',inplace  =True)

# %%
print("Number of Unique App names = ", len(ply['App'].unique()))
print("NUMBER of the Total App name = ", ply.shape[0])
print("Duplicate Apps = ",len(ply['App'])- len(ply['App'].unique()))
# Out:
# Number of Unique App names =  7023
# NUMBER of the Total App name =  7023
# Duplicate Apps =  0

# %%
total = ply.isnull().sum().sort_values(ascending  = False)

# %%
ply.drop_duplicates(subset = 'App', keep = 'first' ,inplace = True)

# %%
ply.dropna(how = 'any',inplace  =True)

# %%
ply.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
total1 = usr.isnull().sum().sort_values(ascending  = False)

# %%
usr.dropna(how='any',inplace=True)

# %%
usr.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# # Problem 1: Which category section have more apps?

# %%
temp = ply['Category'].value_counts().reset_index()
plt.figure(figsize=(12,12))
ax = plt.subplot(111)
plt.pie(x = temp['Category'], labels= temp['index'],autopct= '%1.1f%%',shadow=True)
plt.legend()
plt.title('Distribution of apps according category',size = 20);
ax.legend(bbox_to_anchor=(1.4, 1))
plt.show()

# %% [markdown]
# The above figure is the visualization of distribution
# of apps according to various category sections.We
# can see that most i.e 21.5% of apps in play store
# belongs to “Family”category.The index contains the
# various types of category of apps arranged in
# descending order of number of apps belonging to
# each category.Least number of apps i.e almost 0.5%
# apps belongs to “beauty” Category.

# %% [markdown]
# # Problem 2: Which Category having most installs?

# %%
highest_Installs_df = ply.groupby('Category')[['Installs']].sum().sort_values(by='Installs', ascending=False)

# %%
x2sis = []
y2sis = []

for i in range(len(highest_Installs_df)):
    x2sis.append(highest_Installs_df.Installs[i])
    y2sis.append(highest_Installs_df.index[i])

plt.figure(figsize=(18,13))

plt.xlabel("Installs")
plt.ylabel("Category")
sns.set_theme(style="dark")
graph = sns.barplot(x = x2sis, y = y2sis, alpha =0.9, palette= "viridis")
graph.set_title("Installs", fontsize = 25);

# %% [markdown]
# From the above bar chart we can observe that “Games” category has the most installed apps
# followed by”Family”,”tools,”Communication”
# compared to other category.

# %% [markdown]
# # Problem 3: Which genres have more App?

# %%
top_genres = ply.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = ply.groupby(['Genres'])[['Installs']].sum()

# %%
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_10_genres_installs = top_genres_installs.head(20)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 10 Genres")
sns.set_theme(style="whitegrid")
sns.barplot(top_10_genres_installs.Genres, top_10_genres_installs.Count)
plt.show()

# %% [markdown]
# From the above chart we can conclude that most
# number of apps belongs to
# “Tools”,”Entertainment”,”education”,”Action”
# compared to other Genres

# %% [markdown]
# # Problem 4: Which Genres having most installs?

# %%
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
sns.set_theme(style="darkgrid")
plt.show()

# %% [markdown]
# The above chart contains top 20 Genre having most
# installs.Here we can observe that “Arcade” genre has
# most installed apps followed by”Action” and
# “Tools”.

# %% [markdown]
# # Problem 5: Distribution of Apps according to content rating

# %%
a = ply['Content Rating'].value_counts().index
b = ply['Content Rating'].value_counts()

asis = []
bsis = []
for i in range(len(a)):
    asis.append(a[i])
    bsis.append(b[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(asis,bsis,width=0.8,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
sns.set_theme(style="white")
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# The above chart depicts that most number of apps
# belongs to “Everyone”
# .”Adult 18+” and “Unrated” contains least number
# of apps.

# %% [markdown]
# # Problem 6: Rating analysis

# %%
plt.figure(figsize=(10,7))
sns.distplot(ply['Rating'],color = 'red')
plt.legend(['Rating'])
plt.title('Average rating',size = 20)
plt.show()

# %% [markdown]
#  It is evident from the dist plot visualizations that
# the ratings are still slanted to the left.We are aware that if a variable is skewed, the values
# at the extreme ends of the distribution will affect the
# mean. As a result, the median provides a more
# accurate depiction of the vast majority of values in
# the variable.

# %% [markdown]
# # Problem 7: Percentage of Free Vs Paid Apps in playstore

# %%
plt.figure(figsize=(10,10))
labels = ply['Type'].value_counts(sort = True).index
sizes = ply['Type'].value_counts(sort = True)
colors = ["orange","yellow"]
explode = (0.2,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in playstore',size = 20)
plt.show()

# %% [markdown]
# Here, we can see that 92.2% of the apps on the
# Google Play Store are free, while 7.80% of the apps
# are purchased. This means that the majority of the
# apps are free on the Google Play Store.

# %% [markdown]
# # Problem 8: Most reviewed Apps

# %%
Apps_with_Highest_rev = ply.sort_values(by='Reviews', ascending=False).head(20)

# %%
plt.figure(figsize=(15,12));
plt.pie(Apps_with_Highest_rev .Reviews, explode=None, labels=Apps_with_Highest_rev.App, autopct='%1.1f%%', startangle=0);
plt.title('Most reviewed app',size = 20);
plt.legend(Apps_with_Highest_rev.App, 
           loc="lower right",
           title="Apps",
           fontsize = "xx-small"
          );

# %% [markdown]
# The above diagram depicts the the top 20 most
# reviewed apps.It is analyzed based on the “reviews”
# column from the dataset which contains number of
# reviews given for each app .It is found out that “Clash of clans” is the most reviewed app followed
# by “Subway Surfers”,“Clash Royale”,”Candy Crush
# saga”.We can conclude that gaming apps are
# reviewed the most.

# %% [markdown]
# # Problem 9: Top 5 paid apps

# %%
most_paid_app = ply.sort_values(by='Price', ascending=False).head(5)
most_paid_app
# Out:
#                            App   Category  Rating  Reviews    Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300     10000
# 5354            I am Rich Plus     FAMILY     4.0      856   8.700     10000
# 5351                 I am rich  LIFESTYLE     3.8     3547   1.800    100000
# 5358                I am Rich!    FINANCE     3.8       93  22.000      1000
# 5359        I am rich(premium)    FINANCE     3.5      472   0.965      5000
#
#       Type   Price Content Rating         Genres Last Updated Current Ver  \
# 4367  Paid  400.00       Everyone      Lifestyle   2018-05-03       1.0.1
# 5354  Paid  399.99       Everyone  Entertainment   2018-05-19         3.0
# 5351  Paid  399.99       Everyone      Lifestyle   2018-01-12         2.0
# 5358  Paid  399.99       Everyone        Finance   2017-12-11         1.0
# 5359  Paid  399.99       Everyone        Finance   2017-05-01         3.4
#
#        Android Ver
# 4367    4.1 and up
# 5354    4.4 and up
# 5351  4.0.3 and up
# 5358    4.1 and up
# 5359    4.4 and up

# %%
plt.figure(figsize=(15,12));
plt.pie(most_paid_app .Price, explode=None, labels=most_paid_app.App, startangle=0);
plt.title('Most paid app',size = 20);
plt.legend(most_paid_app.Price, 
           loc="lower right",
           title="Apps",
           fontsize = "xx-small"
          );

# %% [markdown]
# “I'm Rich - Trump Edition”,”I am Rich Plus”,”I am
# rich”,”I am Rich !” and “”I am rich(premium” are
# the top 5 paid apps and the above pie chart is
# representation top 5 paid apps apps as per the price
# of said apps.The index contains price of apps.

# %% [markdown]
# #Problem 10: Correlation map of various coulmns

# %%
merged_df = ply.merge(usr, on="App")

# %%
f,ax = plt.subplots(figsize=(10,6))
sns.heatmap(merged_df.corr(), annot=True, linewidths=.8, fmt= '.2f',ax=ax)
plt.show()

# %% [markdown]
# The Reviews and Installs columns have a
# significant positive association. This is
# essentially evident.The Price has a marginally inverse relationship
# to the Rating, Reviews, and Installs.The Installs and Reviews columns have a
# weakly positive correlation with the Rating.

# %% [markdown]
# # Problem 11: Percentage of positive, negative and nuetral review on a Apps

# %%
counts = list(merged_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (6, 6)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentimets', fontsize=12)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# According to the pie chart above, the majority of the
# apps available on the Google Play store have
# received positive customer evaluations, however
# some apps have garnered mixed reviews.

# %% [markdown]
# # Problem 12: Most words used in review section by users

# %%
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(usr['Translated_Review']))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# The above image is known as “word cloud” which
# graphical representation of mostused words by the
# users in their reviews about various apps.

# %% [markdown]
# # Problem 13: Pricing distribution of paid App

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(ply[ply['Type'] == 'Paid']['Price'], color = 'red', shade = True)
plt.xlabel('Prices of Apps')
plt.title('Pricing Distribution of Paid Apps')
plt.show()

# %% [markdown]
# The above graph is plotted to depict pricing
# distribution of paid apps.From the graph it is very
# clear that the apps which are priced less than
# 100$ are downloaded the most among the paid apps.

# %% [markdown]
# # Problem 14: Impact of Size on Installs

# %%
ply[ply['Type'] == 'Paid']['Price']
# Out:
# 234       4.99
# 235       4.99
# 477       6.99
# 481       7.99
# 851       3.99
#          ...
# 10690     0.99
# 10697     0.99
# 10760     7.99
# 10782    16.99
# 10785     1.20
# Name: Price, Length: 539, dtype: float64

# %%
ply['log_installs'] = np.log2(ply['Installs'])

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(ply['Size'],ply['log_installs'], hue=ply['Type'])
plt.show()

# %% [markdown]
# It is clear from the above mentioned plot that size may impact the number of installations. Bulky applications are less installed by the user.

# %% [markdown]
# # Problem 15: Does sentiment subjectivity proportional to Sentiment polarity

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(usr['Sentiment_Subjectivity'], usr['Sentiment_Polarity'],
                hue = usr['Sentiment'], edgecolor='white', palette="inferno")
plt.title("Google Play Store Reviews Sentiment Analysis", fontsize=20)
plt.show()

# %% [markdown]
# From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low

# %% [markdown]
# # Problem 16: Top 5 positive review apps

# %%
positive_usr=usr[usr['Sentiment']=='Positive']
positive_usr
# Out:
#                          App  \
# 0      10 Best Foods for You
# 1      10 Best Foods for You
# 3      10 Best Foods for You
# 4      10 Best Foods for You
# 5      10 Best Foods for You
# ...                      ...
# 17147             Bowmasters
# 17148             Bowmasters
# 17151             Bowmasters
# 17152             Bowmasters
# 17153             Bowmasters
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 17147  Crashes every often I've playing awhile, fun g...  Positive
# 17148  Really great game... content requires purchase...  Positive
# 17151  Screen freezes sometimes slows making accuracy...  Positive
# 17152               It great game laggy. That's problem.  Positive
# 17153  Pretty good game Loved it!Great time killer I'...  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 17147            0.133333                0.400000
# 17148            0.200000                0.575000
# 17151            0.050000                0.700000
# 17152            0.200000                0.575000
# 17153            0.312500                0.700000
#
# [6738 rows x 5 columns]

# %%
positive_usr.groupby('App')['Sentiment'].value_counts().nlargest(5).plot.barh(figsize=(10,8),color='skyblue').invert_yaxis()
plt.title("Top 5 positive review apps")
plt.xlabel('Total number of positive reviews')
plt.legend();

# %% [markdown]
# Apps having most positive reviews are”Helix
# umap”,”Duolings,“Learn languages free”,”Caloire
# Counter””Bowmasters” and”Calorie counter”.

# %% [markdown]
# # Problem 17: Top 5 Negative review apps

# %%
negative_usr=usr[usr['Sentiment']=='Negative']
negative_usr
# Out:
#                          App  \
# 32     10 Best Foods for You
# 43     10 Best Foods for You
# 68     10 Best Foods for You
# 85     10 Best Foods for You
# 95     10 Best Foods for You
# ...                      ...
# 17136             Bowmasters
# 17139             Bowmasters
# 17141             Bowmasters
# 17143             Bowmasters
# 17150             Bowmasters
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# ...                                                  ...       ...
# 17136    Perfect game.. A Biiittt violent bloody though.  Negative
# 17139  HORIBAL game horrible fact go bow arrow people...  Negative
# 17141  THIS SUCKS HORRIBLE CONTROLS AND THE GRAPHICS ...  Negative
# 17143  I LOVE THIS GAME IT'S AN AMAZING GAME PLEASE I...  Negative
# 17150  ADS everywhere! Before match, claiming chests,...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 32               -0.50000                 0.50000
# 43               -0.20000                 0.00000
# 68               -0.20000                 0.00000
# 85               -0.80000                 0.80000
# 95               -0.32500                 0.47500
# ...                   ...                     ...
# 17136            -0.25000                 0.82500
# 17139            -0.33125                 0.49375
# 17141            -0.67500                 0.67500
# 17143            -0.01250                 0.41250
# 17150            -0.70000                 0.70000
#
# [2569 rows x 5 columns]

# %%
negative_usr.groupby('App')['Sentiment'].value_counts().nlargest(5).plot.barh(figsize=(15,8),color='lightpink').invert_yaxis()
plt.title("Top 5 negative review apps")
plt.xlabel('Total number of negative reviews')
plt.legend();

# %% [markdown]
# Apps having most Negative reviews are”Angry
# birds”.”Candy crush Saga”,”Bowmaster”,” 8 ball
# pool” and “Candy crush Soda saga”.

# %% [markdown]
# # Problem 18: Which App generated most revenue?

# %%
ply_paid=ply[ply['Type']=='Paid']
ply_free=ply[ply['Type']=='Free']

# %%
#Creating new column Revenue
ply_paid['Revenue'] = ply_paid['Installs']*ply_paid['Price']

# %%
ply_paid['Revenue'] = ply_paid['Installs']*ply_paid['Price']

# %%
ply_paid_revenue_sorted=ply_paid.sort_values(by='Revenue', ascending=False)
revenue_sorted_Price = ply_paid_revenue_sorted.sort_values(by='Price', ascending=False).head(5)
revenue_sorted_Price
# Out:
#                                  App   Category  Rating  Reviews   Size  \
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.300
# 5351                       I am rich  LIFESTYLE     3.8     3547  1.800
# 5359              I am rich(premium)    FINANCE     3.5      472  0.965
# 5364  I am rich (Most expensive app)    FINANCE     4.1      129  2.700
# 4197          most expensive app (H)     FAMILY     4.3        6  1.500
#
#       Installs  Type   Price Content Rating         Genres Last Updated  \
# 4367     10000  Paid  400.00       Everyone      Lifestyle   2018-05-03
# 5351    100000  Paid  399.99       Everyone      Lifestyle   2018-01-12
# 5359      5000  Paid  399.99       Everyone        Finance   2017-05-01
# 5364      1000  Paid  399.99           Teen        Finance   2017-12-06
# 4197       100  Paid  399.99       Everyone  Entertainment   2018-07-16
#
#      Current Ver   Android Ver  log_installs     Revenue
# 4367       1.0.1    4.1 and up     13.287712   4000000.0
# 5351         2.0  4.0.3 and up     16.609640  39999000.0
# 5359         3.4    4.4 and up     12.287712   1999950.0
# 5364           2  4.0.3 and up      9.965784    399990.0
# 4197         1.0    7.0 and up      6.643856     39999.0

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.set_theme(style="ticks")
sns.barplot(revenue_sorted_Price.App,revenue_sorted_Price.Revenue)
plt.show()

# %% [markdown]
# Revenue is calculated by price multiplied to the
# number of installs of an app,Above chart contains
# top 5 apps most revenue and we can observe that “ I
# m rich trump edition” has generated most revenue
# followed by “ I m rich”.

# %% [markdown]
# # Problem 19: Impact of Last update of Apps on rating

# %%
print(ply['Last Updated'].head())
#fetch update year from date
ply["Update year"] = ply["Last Updated"].apply(lambda x: x.strftime('%Y')).astype('int64')
# Out:
# 0   2018-01-07
# 1   2018-01-15
# 2   2018-08-01
# 3   2018-06-08
# 4   2018-06-20
# Name: Last Updated, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.regplot(x="Update year", y="Rating", data=ply)
plt.title("Update Year VS Rating");

# %% [markdown]
# From the above plot we can observe acclamation of
# rating increases with update year.it can be concluded
# that rating is directly proportional to last update of
# apps.

# %% [markdown]
# # Problem 20: In which month apps are updated the most?

# %%
ply_paid["Update month"] = ply_paid["Last Updated"].apply(lambda x: x.strftime('%m')).astype('int64') 
ply_free["Update month"] = ply_free["Last Updated"].apply(lambda x: x.strftime('%m')).astype('int64')

# %%
#Checking paid Apps update over month
ply_paid.groupby("Update month")["App"].count().plot.bar(figsize=(10,8), color= "red")
plt.title("Paid Apps update over the month", size=20)
plt.legend();

# %%
#Checking free Apps update over month
ply_free.groupby("Update month")["App"].count().plot.bar(figsize=(10,8), color='orange')
plt.title("Free Apps update over the month", size=20)
plt.legend();

# %% [markdown]
# Both free and paid apps are updated the most in the
# month of July and least in the month of September.

# %% [markdown]
# # Conclusion
# Through exploratory data analysis, we were able to
# identify some patterns and draw some conclusions
# that may help app succeed on the play store.
# * “Family” category section have most apps
# * “Game” Category having most installs
# * “Tools” genre have most Apps
# * “Arcade”genre have most installs
# * Most number of apps are rated “Everyone”
# * Majority of the apps are free on the Google Play
# Store.
# * Gaming apps are reviewed the most.
# * The majority of the apps available on the Google
# Play store have received positive customer
# evaluations, however some apps have garnered
# mixed reviews.
# * The apps which are priced less than 100$ are
# downloaded the most among the paid apps
# * Bulky applications are less installed by the user.  I m rich trump edition” has generated most
# revenue
# * That rating is directly proportional to last update
# of apps
# * Both free and paid apps are updated the most in
# the month of July and least in the month of
# September

# %% [markdown]
# # Challenges Faced
# * Reading the dataset and comprehending the problem statement.
# * Handling error, duplicate values and NaN values in the dataset.
# * Designing multiple visualizations to summarize the information gathered from dataset and successfully communicate the results and trends to reader.
